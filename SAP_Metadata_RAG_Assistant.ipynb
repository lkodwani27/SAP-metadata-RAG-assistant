# %% [markdown]
# <a href="https://colab.research.google.com/github/lkodwani27/SAP-metadata-RAG-assistant/blob/main/SAP_Metadata_RAG_Assistant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AI-Powered Enterprise(SAP) Data Discovery Assistant Using RAG
#
# ## Project Overview
#
# In modern enterprises, large volumes of data are distributed across multiple systems, departments, and platforms.
# Although organizations maintain metadata catalogs, discovering the right dataset is often difficult for both technical and business users.
#
# Traditional keyword-based search systems:
# - Lack semantic understanding
# - Require technical expertise
# - Do not provide conversational exploration
# - Often lead to poor data discoverability
#
# This project demonstrates how Retrieval-Augmented Generation (RAG) can transform a static metadata catalog into an intelligent conversational discovery assistant.
#
# Using semantic search and Large Language Models (LLMs), users can explore enterprise metadata using natural language queries such as:
#
# - “Which dataset contains customer revenue information?”
# - “Find tables related to employee attendance.”
# - “Which datasets are missing ownership information?”
# - “Explain the customer_orders table.”
#
# ---
#
# # Project Objectives
#
# The primary objective of this project is to build a lightweight AI-powered metadata discovery assistant that:
#
# - Makes enterprise metadata searchable using natural language
# - Uses semantic embeddings for intelligent dataset discovery
# - Retrieves grounded schema context to reduce hallucinations
# - Generates business-friendly dataset explanations using an LLM
# - Identifies metadata governance gaps
#
# ---
#
# # Learning Outcomes
#
# By completing this notebook, you will learn how to:
#
# - Build a Retrieval-Augmented Generation (RAG) pipeline
# - Generate semantic embeddings using Sentence Transformers
# - Perform vector similarity search using FAISS
# - Retrieve contextual metadata intelligently
# - Use FLAN-T5 for grounded response generation
# - Create a conversational enterprise metadata assistant
#
# ---
#
# # Technologies Used
#
# | Component | Technology |
# |---|---|
# | Development Environment | Google Colab |
# | Programming Language | Python |
# | Data Processing | Pandas |
# | Embedding Model | Sentence Transformers |
# | Vector Search | FAISS |
# | LLM | FLAN-T5 |
# | AI Framework | Hugging Face Transformers |
#
# ---
#
# # Expected Outputs
#
# At the end of this project, the assistant will be capable of generating:
#
# - Dataset discovery recommendations
# - Natural language metadata explanations
# - Semantic dataset search results
# - Governance gap summaries
# - Conversational metadata responses
#
# ---
#
# # RAG Workflow
#
# User Query
# ↓
# Semantic Search
# ↓
# Retrieve Relevant Metadata
# ↓
# Provide Context to LLM
# ↓
# Generate Grounded Response
#
# ---
#
# # Dataset Used
#
# This project uses a synthetic enterprise metadata catalog containing:
# - Table names
# - Column names
# - Data types
# - Business descriptions
# - Ownership information
# - Governance metadata
#
# No live data warehouse or enterprise system is required.

# %% [markdown]
# # Step 1: Install Required Libraries
#
# In this step, we install all the libraries required to build the AI-Powered SAP Data Discovery Assistant using RAG.
#
# These libraries help us perform:
# - Metadata processing
# - Embedding generation
# - Vector similarity search
# - LLM-based response generation

# %%
# Install required libraries

# !pip install q pandas
# !pip install q sentence-transformers
# !pip install q faiss-cpu
# !pip install q transformers
# !pip install q numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 48.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Step 2: Import Required Libraries
#
# In this step, we import the libraries required for:
# - Metadata processing
# - Embedding generation
# - Vector similarity search
# - LLM-based response generation

# %%
#Data Processing
import pandas as pd
import numpy as np

#Vector Search
import faiss

# Embedding model
from sentence_transformers import SentenceTransformer

# LLM
from transformers import pipeline
